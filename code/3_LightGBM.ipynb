# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import optuna
from optuna.samplers import TPESampler
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Import preprocessing utilities
from util.preprocess import preprocess
from util.geo_data import add_geo_data

# %%
print("="*80)
print("HDB Resale Price Prediction - Hyperparameter Optimization")
print("="*80)
# Out:
# ================================================================================
# HDB Resale Price Prediction - Hyperparameter Optimization
# ================================================================================

# %%
print("\nLoading data...")
train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")
# Out:
# Loading data...

# %%
print(f"Train shape: {train_df.shape}")
print(f"Test shape: {test_df.shape}")
# Out:
# Train shape: (162691, 11)
# Test shape: (50000, 10)

# %%
# Preprocess data
print("\nPreprocessing data...")
train_processed = preprocess(train_df)
test_processed = preprocess(test_df)
# Out:
# Preprocessing data...

# %%
print("Adding geographical features...")
train_processed = add_geo_data(train_processed)
test_processed = add_geo_data(test_processed)
# Out:
# Adding geographical features...

# %%
# Prepare features for modeling
y_train = train_processed['RESALE_PRICE'].values
feature_cols = [col for col in train_processed.columns if col not in ['RESALE_PRICE', 'MONTH']]

# %%
# Identify categorical and numerical columns
categorical_cols = ['TOWN', 'FLAT_TYPE', 'BLOCK', 'STREET', 'FLOOR_RANGE', 'FLAT_MODEL']
numerical_cols = [col for col in feature_cols if col not in categorical_cols]

# %%
# Prepare dataframes for modeling
X_train = train_processed[feature_cols].copy()
X_test = test_processed[feature_cols].copy()

# %%
# Handle categorical variables
for col in categorical_cols:
    if col in X_train.columns:
        X_train[col] = X_train[col].astype('category')
        X_test[col] = X_test[col].astype('category')

# %%
# Handle missing values if any
if X_train.isnull().any().any():
    print("\nHandling missing values...")
    for col in X_train.columns:
        if X_train[col].isnull().any():
            if col in numerical_cols:
                median_val = X_train[col].median()
                X_train[col].fillna(median_val, inplace=True)
                X_test[col].fillna(median_val, inplace=True)
            else:
                mode_val = X_train[col].mode()[0] if len(X_train[col].mode()) > 0 else 'unknown'
                X_train[col].fillna(mode_val, inplace=True)
                X_test[col].fillna(mode_val, inplace=True)

# %%
print("\n" + "="*80)
print("Starting Hyperparameter Optimization with Optuna")
print("="*80)
# Out:
# ================================================================================
# Starting Hyperparameter Optimization with Optuna
# ================================================================================

# %%
# Define objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'boosting_type': 'gbdt',
        'verbosity': -1,
        'force_col_wise': True,
        'random_state': 42,
        
        # Hyperparameters to optimize
        'num_leaves': trial.suggest_int('num_leaves', 50, 150),
        'max_depth': trial.suggest_int('max_depth', -1, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.05, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 2000, 6000),
        
        'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 0.9),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 0.9),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 30),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.0001, 0.01, log=True),
        
        'lambda_l1': trial.suggest_float('lambda_l1', 0.0, 2.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 0.0, 2.0),
        
        'min_split_gain': trial.suggest_float('min_split_gain', 0.0, 0.05),
        'max_bin': trial.suggest_int('max_bin', 200, 300),
    }
    
    # 3-Fold CV for faster optimization (will use 5-fold for final model)
    n_splits = 3
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    cv_scores = []
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X_train), 1):
        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train[train_idx], y_train[val_idx]
        
        # Create LightGBM datasets
        train_data = lgb.Dataset(X_tr, label=y_tr, categorical_feature='auto')
        val_data = lgb.Dataset(X_val, label=y_val, reference=train_data, categorical_feature='auto')
        
        # Train model
        model = lgb.train(
            params,
            train_data,
            num_boost_round=params['n_estimators'],
            valid_sets=[val_data],
            callbacks=[
                lgb.early_stopping(stopping_rounds=150, verbose=False),
            ]
        )
        
        # Predictions
        y_pred = model.predict(X_val, num_iteration=model.best_iteration)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        cv_scores.append(rmse)
    
    mean_rmse = np.mean(cv_scores)
    return mean_rmse

# %%
# Create Optuna study
print("\nStarting Optuna optimization...")
study = optuna.create_study(
    direction='minimize',
    sampler=TPESampler(seed=42),
    study_name='lgb_hdb_optimization'
)
# Out:
# [I 2025-11-06 09:30:52,176] A new study created in memory with name: lgb_hdb_optimization
# Starting Optuna optimization...

# %%
# Run optimization
study.optimize(
    objective,
    n_trials=100,
    timeout=18000,  
    show_progress_bar=True,
    n_jobs=1
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-11-06 09:31:42,276] Trial 0 finished with value: 25765.957731719278 and parameters: {'num_leaves': 87, 'max_depth': 15, 'learning_rate': 0.026975154833351143, 'n_estimators': 4395, 'feature_fraction': 0.5624074561769746, 'bagging_fraction': 0.562397808134481, 'bagging_freq': 1, 'min_child_samples': 28, 'min_child_weight': 0.0015930522616241021, 'lambda_l1': 1.416145155592091, 'lambda_l2': 0.041168988591604894, 'min_split_gain': 0.04849549260809972, 'max_bin': 284}. Best is trial 0 with value: 25765.957731719278.
# [I 2025-11-06 09:31:53,233] Trial 1 finished with value: 39769.346127534714 and parameters: {'num_leaves': 71, 'max_depth': 2, 'learning_rate': 0.007627364729026304, 'n_estimators': 3217, 'feature_fraction': 0.7099025726528951, 'bagging_fraction': 0.6727780074568463, 'bagging_freq': 3, 'min_child_samples': 22, 'min_child_weight': 0.00019010245319870352, 'lambda_l1': 0.5842892970704363, 'lambda_l2': 0.7327236865873834, 'min_split_gain': 0.0228034992108518, 'max_bin': 279}. Best is trial 0 with value: 25765.957731719278.
# [I 2025-11-06 09:32:15,434] Trial 2 finished with value: 26978.591704215283 and parameters: {'num_leaves': 70, 'max_depth': 7, 'learning_rate': 0.019560708142748476, 'n_estimators': 2185, 'feature_fraction': 0.7430179407605754, 'bagging_fraction': 0.5682096494749166, 'bagging_freq': 1, 'min_child_samples': 29, 'min_child_weight': 0.00853618986286683, 'lambda_l1': 1.6167946962329223, 'lambda_l2': 0.6092275383467414, 'min_split_gain': 0.004883605700319194, 'max_bin': 269}. Best is trial 0 with value: 25765.957731719278.
# [I 2025-11-06 09:32:20,822] Trial 3 finished with value: 53422.753062613345 and parameters: {'num_leaves': 94, 'max_depth': 1, 'learning_rate': 0.015636765183901856, 'n_estimators': 2137, 'feature_fraction': 0.8637281608315128, 'bagging_fraction': 0.6035119926400068, 'bagging_freq': 5, 'min_child_samples': 16, 'min_child_weight': 0.001096821720752952, 'lambda_l1': 1.0934205586865593, 'lambda_l2': 0.3697089110510541, 'min_split_gain': 0.048479231388227934, 'max_bin': 278}. Best is trial 0 with value: 25765.957731719278.
# [I 2025-11-06 09:33:15,919] Trial 4 finished with value: 25559.026749422395 and parameters: {'num_leaves': 144, 'max_depth': 14, 'learning_rate': 0.019809338952032924, 'n_estimators': 5688, 'feature_fraction': 0.5353970008207678, 'bagging_fraction': 0.578393144967658, 'bagging_freq': 1, 'min_child_samples': 16, 'min_child_weight': 0.0005989003672254305, 'lambda_l1': 0.5426980635477918, 'lambda_l2': 1.6574750183038587, 'min_split_gain': 0.017837666334679463, 'max_bin': 228}. Best is trial 4 with value: 25559.026749422395.
# [I 2025-11-06 09:33:23,227] Trial 5 finished with value: 47389.61183550453 and parameters: {'num_leaves': 104, 'max_depth': 1, 'learning_rate': 0.03170786387747639, 'n_estimators': 2298, 'feature_fraction': 0.8947547746402069, 'bagging_fraction': 0.808897907718663, 'bagging_freq': 2, 'min_child_samples': 10, 'min_child_weight': 0.004274869455295219, 'lambda_l1': 1.4137146876952342, 'lambda_l2': 1.4580143360819746, 'min_split_gain': 0.03856351733429729, 'max_bin': 207}. Best is trial 4 with value: 25559.026749422395.
# [I 2025-11-06 09:34:08,173] Trial 6 finished with value: 26102.713200591097 and parameters: {'num_leaves': 86, 'max_depth': 0, 'learning_rate': 0.03648156244855578, 'n_estimators': 4493, 'feature_fraction': 0.6323592099410597, 'bagging_fraction': 0.5254233401144095, 'bagging_freq': 3, 'min_child_samples': 16, 'min_child_weight': 0.002878805718308925, 'lambda_l1': 1.2751149427104262, 'lambda_l2': 1.774425485152653, 'min_split_gain': 0.023610746258097465, 'max_bin': 212}. Best is trial 4 with value: 25559.026749422395.
# [I 2025-11-06 09:35:09,390] Trial 7 finished with value: 25889.180541006004 and parameters: {'num_leaves': 122, 'max_depth': 11, 'learning_rate': 0.018207369334074977, 'n_estimators': 5084, 'feature_fraction': 0.6975182385457563, 'bagging_fraction': 0.7090931317527976, 'bagging_freq': 3, 'min_child_samples': 10, 'min_child_weight': 0.00016435497475111326, 'lambda_l1': 0.0628583713734685, 'lambda_l2': 1.2728208225275608, 'min_split_gain': 0.015717799053816334, 'max_bin': 251}. Best is trial 4 with value: 25559.026749422395.
# [I 2025-11-06 09:35:27,096] Trial 8 finished with value: 31112.018574579633 and parameters: {'num_leaves': 141, 'max_depth': 3, 'learning_rate': 0.01286331566624978, 'n_estimators': 5022, 'feature_fraction': 0.591519266196649, 'bagging_fraction': 0.5307919639315172, 'bagging_freq': 3, 'min_child_samples': 13, 'min_child_weight': 0.007234279845665418, 'lambda_l1': 1.616240759128834, 'lambda_l2': 1.266807513020847, 'min_split_gain': 0.04357302950938589, 'max_bin': 281}. Best is trial 4 with value: 25559.026749422395.
# [I 2025-11-06 09:36:55,799] Trial 9 finished with value: 26485.49182938217 and parameters: {'num_leaves': 68, 'max_depth': 14, 'learning_rate': 0.017310604986467974, 'n_estimators': 5230, 'feature_fraction': 0.8584365199693973, 'bagging_fraction': 0.6272013899887455, 'bagging_freq': 1, 'min_child_samples': 14, 'min_child_weight': 0.0007148510793512986, 'lambda_l1': 1.6360295318449862, 'lambda_l2': 1.7214611665126869, 'min_split_gain': 0.0003476065265595352, 'max_bin': 251}. Best is trial 4 with value: 25559.026749422395.
# [I 2025-11-06 09:38:34,883] Trial 10 finished with value: 25764.749296404054 and parameters: {'num_leaves': 148, 'max_depth': 10, 'learning_rate': 0.005087651134649415, 'n_estimators': 5821, 'feature_fraction': 0.5058492787160821, 'bagging_fraction': 0.8630659181130071, 'bagging_freq': 7, 'min_child_samples': 23, 'min_child_weight': 0.00043633621401069724, 'lambda_l1': 0.6642283504310382, 'lambda_l2': 1.9833677992566372, 'min_split_gain': 0.03485779491700472, 'max_bin': 227}. Best is trial 4 with value: 25559.026749422395.
# [I 2025-11-06 09:40:17,465] Trial 11 finished with value: 25719.12645729682 and parameters: {'num_leaves': 150, 'max_depth': 10, 'learning_rate': 0.00523615999948625, 'n_estimators': 5978, 'feature_fraction': 0.5017197236881715, 'bagging_fraction': 0.8752660310188901, 'bagging_freq': 7, 'min_child_samples': 22, 'min_child_weight': 0.00044008275954576695, 'lambda_l1': 0.6429414312356754, 'lambda_l2': 1.914417269779166, 'min_split_gain': 0.035058129769687994, 'max_bin': 226}. Best is trial 4 with value: 25559.026749422395.
# [I 2025-11-06 09:41:51,536] Trial 12 finished with value: 25553.43599834137 and parameters: {'num_leaves': 129, 'max_depth': 11, 'learning_rate': 0.009475092623848576, 'n_estimators': 5968, 'feature_fraction': 0.5007316634086578, 'bagging_fraction': 0.7499392420795297, 'bagging_freq': 7, 'min_child_samples': 19, 'min_child_weight': 0.00037743253269482453, 'lambda_l1': 0.6200744542112027, 'lambda_l2': 1.970933004259456, 'min_split_gain': 0.014602035035622045, 'max_bin': 235}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:43:02,192] Trial 13 finished with value: 25754.68363635299 and parameters: {'num_leaves': 127, 'max_depth': 13, 'learning_rate': 0.00978478695676993, 'n_estimators': 3591, 'feature_fraction': 0.5662225125541511, 'bagging_fraction': 0.7518353156411048, 'bagging_freq': 5, 'min_child_samples': 19, 'min_child_weight': 0.0003175721627012876, 'lambda_l1': 0.21567239079958284, 'lambda_l2': 1.5620772882739202, 'min_split_gain': 0.013168694362168724, 'max_bin': 233}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:44:02,228] Trial 14 finished with value: 26022.65892813972 and parameters: {'num_leaves': 126, 'max_depth': 7, 'learning_rate': 0.010443416000580203, 'n_estimators': 5540, 'feature_fraction': 0.6244239369140131, 'bagging_fraction': 0.7693087163058641, 'bagging_freq': 5, 'min_child_samples': 18, 'min_child_weight': 0.00010072274821000552, 'lambda_l1': 0.40634985605643714, 'lambda_l2': 1.1131644321643601, 'min_split_gain': 0.013742647449763137, 'max_bin': 244}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:44:50,780] Trial 15 finished with value: 25687.00143193631 and parameters: {'num_leaves': 113, 'max_depth': 12, 'learning_rate': 0.02447058937907161, 'n_estimators': 4604, 'feature_fraction': 0.5328419617855736, 'bagging_fraction': 0.7138624300191921, 'bagging_freq': 6, 'min_child_samples': 25, 'min_child_weight': 0.0007680423243309346, 'lambda_l1': 0.876698942906609, 'lambda_l2': 1.5591534428925946, 'min_split_gain': 0.02893406245887535, 'max_bin': 217}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:46:10,560] Trial 16 finished with value: 25838.133868771332 and parameters: {'num_leaves': 137, 'max_depth': 9, 'learning_rate': 0.007300737641218352, 'n_estimators': 5499, 'feature_fraction': 0.6470734248469445, 'bagging_fraction': 0.6536299599290021, 'bagging_freq': 4, 'min_child_samples': 17, 'min_child_weight': 0.0013639604752094935, 'lambda_l1': 0.9125416786738956, 'lambda_l2': 0.9073210715005746, 'min_split_gain': 0.007692966336023909, 'max_bin': 241}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:46:33,206] Trial 17 finished with value: 27548.851618478 and parameters: {'num_leaves': 112, 'max_depth': 4, 'learning_rate': 0.04327783754961466, 'n_estimators': 3819, 'feature_fraction': 0.788764421801138, 'bagging_fraction': 0.8177821035896214, 'bagging_freq': 6, 'min_child_samples': 13, 'min_child_weight': 0.0002762669989497379, 'lambda_l1': 0.32668208173998625, 'lambda_l2': 1.7540482061151421, 'min_split_gain': 0.017955817191096575, 'max_bin': 298}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:48:03,178] Trial 18 finished with value: 25582.688616290427 and parameters: {'num_leaves': 135, 'max_depth': 15, 'learning_rate': 0.012039803971715776, 'n_estimators': 5964, 'feature_fraction': 0.5541761658612747, 'bagging_fraction': 0.7539098636294764, 'bagging_freq': 2, 'min_child_samples': 20, 'min_child_weight': 0.0005549808822108256, 'lambda_l1': 1.9025431165190532, 'lambda_l2': 1.3984226927816985, 'min_split_gain': 0.027723228069577555, 'max_bin': 261}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:48:30,002] Trial 19 finished with value: 26106.97394090596 and parameters: {'num_leaves': 52, 'max_depth': 8, 'learning_rate': 0.023283801106749262, 'n_estimators': 2877, 'feature_fraction': 0.6003833262111838, 'bagging_fraction': 0.609576651207506, 'bagging_freq': 4, 'min_child_samples': 25, 'min_child_weight': 0.0018536425291146709, 'lambda_l1': 0.48684876940443533, 'lambda_l2': 1.9988269881753706, 'min_split_gain': 0.008750623187986984, 'max_bin': 225}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:49:50,019] Trial 20 finished with value: 25874.49100355145 and parameters: {'num_leaves': 115, 'max_depth': 12, 'learning_rate': 0.007485849174391141, 'n_estimators': 4787, 'feature_fraction': 0.6653505075720606, 'bagging_fraction': 0.6785895385113576, 'bagging_freq': 6, 'min_child_samples': 20, 'min_child_weight': 0.0002375093728259178, 'lambda_l1': 0.7670977505457562, 'lambda_l2': 1.088492423543757, 'min_split_gain': 0.01974050617501135, 'max_bin': 202}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:51:11,089] Trial 21 finished with value: 25581.92759583698 and parameters: {'num_leaves': 135, 'max_depth': 15, 'learning_rate': 0.013385810811178971, 'n_estimators': 5624, 'feature_fraction': 0.5428192228430327, 'bagging_fraction': 0.7479547664003372, 'bagging_freq': 2, 'min_child_samples': 20, 'min_child_weight': 0.0005390400097667366, 'lambda_l1': 1.876093655187994, 'lambda_l2': 1.362068308162065, 'min_split_gain': 0.02764967226037004, 'max_bin': 255}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:52:29,522] Trial 22 finished with value: 25598.00452140717 and parameters: {'num_leaves': 134, 'max_depth': 13, 'learning_rate': 0.01410681563683641, 'n_estimators': 5524, 'feature_fraction': 0.5242789807041985, 'bagging_fraction': 0.7896020175548094, 'bagging_freq': 2, 'min_child_samples': 15, 'min_child_weight': 0.0006743143235518528, 'lambda_l1': 1.0946948905968836, 'lambda_l2': 1.6635361119855072, 'min_split_gain': 0.029315172861319898, 'max_bin': 238}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:54:09,208] Trial 23 finished with value: 25620.618268031758 and parameters: {'num_leaves': 144, 'max_depth': 15, 'learning_rate': 0.010863417192472776, 'n_estimators': 5593, 'feature_fraction': 0.5996033957685135, 'bagging_fraction': 0.7258358611694571, 'bagging_freq': 2, 'min_child_samples': 20, 'min_child_weight': 0.0003864049589787225, 'lambda_l1': 1.8496298344101267, 'lambda_l2': 1.3368684463490135, 'min_split_gain': 0.020670320961992377, 'max_bin': 260}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:55:30,121] Trial 24 finished with value: 25678.629200117703 and parameters: {'num_leaves': 130, 'max_depth': 13, 'learning_rate': 0.008687114142487289, 'n_estimators': 4206, 'feature_fraction': 0.5445555871357117, 'bagging_fraction': 0.8458176136819662, 'bagging_freq': 1, 'min_child_samples': 18, 'min_child_weight': 0.0009828020978180307, 'lambda_l1': 0.19826914942679685, 'lambda_l2': 1.8313974007958889, 'min_split_gain': 0.011103506407739865, 'max_bin': 258}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:56:47,118] Trial 25 finished with value: 25664.12453151964 and parameters: {'num_leaves': 119, 'max_depth': 11, 'learning_rate': 0.014451927062141203, 'n_estimators': 5258, 'feature_fraction': 0.5690572200768771, 'bagging_fraction': 0.7355020406970143, 'bagging_freq': 4, 'min_child_samples': 24, 'min_child_weight': 0.00012621295260225254, 'lambda_l1': 0.8272987326386403, 'lambda_l2': 1.5918956083647626, 'min_split_gain': 0.02632531391077334, 'max_bin': 233}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:57:42,048] Trial 26 finished with value: 25612.206431745184 and parameters: {'num_leaves': 140, 'max_depth': 14, 'learning_rate': 0.02048701801065486, 'n_estimators': 4778, 'feature_fraction': 0.5068937761571827, 'bagging_fraction': 0.6813094145714219, 'bagging_freq': 2, 'min_child_samples': 22, 'min_child_weight': 0.0005666375146460569, 'lambda_l1': 1.0551727355778515, 'lambda_l2': 1.441184608047255, 'min_split_gain': 0.03375729171905015, 'max_bin': 220}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 09:58:21,645] Trial 27 finished with value: 27100.883397433692 and parameters: {'num_leaves': 107, 'max_depth': 5, 'learning_rate': 0.009191883593076199, 'n_estimators': 5724, 'feature_fraction': 0.5300944644685077, 'bagging_fraction': 0.7859601383007154, 'bagging_freq': 1, 'min_child_samples': 12, 'min_child_weight': 0.0023751176165711135, 'lambda_l1': 1.9953835535316258, 'lambda_l2': 1.8496118773566361, 'min_split_gain': 0.01676074336272207, 'max_bin': 244}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 10:00:02,197] Trial 28 finished with value: 25787.218938226888 and parameters: {'num_leaves': 127, 'max_depth': 12, 'learning_rate': 0.00654618202135343, 'n_estimators': 5311, 'feature_fraction': 0.5809623923017507, 'bagging_fraction': 0.895317972352401, 'bagging_freq': 7, 'min_child_samples': 18, 'min_child_weight': 0.0010636691351418655, 'lambda_l1': 0.5537724613758482, 'lambda_l2': 0.8700400509480988, 'min_split_gain': 0.031747504840033205, 'max_bin': 234}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 10:01:19,007] Trial 29 finished with value: 25581.053288814743 and parameters: {'num_leaves': 145, 'max_depth': 14, 'learning_rate': 0.012371104776212997, 'n_estimators': 4169, 'feature_fraction': 0.6153232117895646, 'bagging_fraction': 0.5731942631529883, 'bagging_freq': 1, 'min_child_samples': 27, 'min_child_weight': 0.00022325887005990107, 'lambda_l1': 0.024791454198633045, 'lambda_l2': 1.1737227025277348, 'min_split_gain': 0.02192629532698839, 'max_bin': 268}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 10:01:58,768] Trial 30 finished with value: 25849.87605099872 and parameters: {'num_leaves': 150, 'max_depth': 14, 'learning_rate': 0.03175186496808703, 'n_estimators': 4219, 'feature_fraction': 0.6689048539919824, 'bagging_fraction': 0.5608305519567616, 'bagging_freq': 1, 'min_child_samples': 27, 'min_child_weight': 0.00022058179056906352, 'lambda_l1': 0.033902925581455134, 'lambda_l2': 0.3714653935858351, 'min_split_gain': 0.02152700970851667, 'max_bin': 297}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 10:03:00,232] Trial 31 finished with value: 25611.288278455613 and parameters: {'num_leaves': 143, 'max_depth': 15, 'learning_rate': 0.0123242640777008, 'n_estimators': 2737, 'feature_fraction': 0.5530777321121435, 'bagging_fraction': 0.5673429255846006, 'bagging_freq': 1, 'min_child_samples': 27, 'min_child_weight': 0.00033025631133353764, 'lambda_l1': 0.301944236663128, 'lambda_l2': 1.1964210113392797, 'min_split_gain': 0.02426131912997168, 'max_bin': 269}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 10:04:13,204] Trial 32 finished with value: 25643.286580227807 and parameters: {'num_leaves': 135, 'max_depth': 14, 'learning_rate': 0.015868160317425568, 'n_estimators': 4917, 'feature_fraction': 0.6167804948772616, 'bagging_fraction': 0.6507652665685747, 'bagging_freq': 2, 'min_child_samples': 30, 'min_child_weight': 0.00017737416824773866, 'lambda_l1': 0.707828462710361, 'lambda_l2': 1.6205857271958763, 'min_split_gain': 0.01803116462299411, 'max_bin': 271}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 10:05:05,100] Trial 33 finished with value: 25587.655824136575 and parameters: {'num_leaves': 144, 'max_depth': 13, 'learning_rate': 0.020938357672985772, 'n_estimators': 3413, 'feature_fraction': 0.5263676102989336, 'bagging_fraction': 0.603871138619221, 'bagging_freq': 1, 'min_child_samples': 21, 'min_child_weight': 0.0005257184846923099, 'lambda_l1': 0.4933127466353919, 'lambda_l2': 1.0077517861901237, 'min_split_gain': 0.024393486569723163, 'max_bin': 288}. Best is trial 12 with value: 25553.43599834137.
# [I 2025-11-06 10:06:24,043] Trial 34 finished with value: 25549.00447025088 and parameters: {'num_leaves': 131, 'max_depth': 11, 'learning_rate': 0.013221495467206206, 'n_estimators': 6000, 'feature_fraction': 0.573589125192213, 'bagging_fraction': 0.5089614490576642, 'bagging_freq': 3, 'min_child_samples': 16, 'min_child_weight': 0.00014208111692489886, 'lambda_l1': 0.13158651289283263, 'lambda_l2': 0.6979758141442916, 'min_split_gain': 0.013843607362722868, 'max_bin': 255}. Best is trial 34 with value: 25549.00447025088.
# [I 2025-11-06 10:07:42,093] Trial 35 finished with value: 25606.797686001373 and parameters: {'num_leaves': 97, 'max_depth': 11, 'learning_rate': 0.011022604820531247, 'n_estimators': 5986, 'feature_fraction': 0.5762415146400749, 'bagging_fraction': 0.5032652026738745, 'bagging_freq': 3, 'min_child_samples': 16, 'min_child_weight': 0.00013261922511526966, 'lambda_l1': 0.1346556378864171, 'lambda_l2': 0.6079520982294428, 'min_split_gain': 0.0029840235315477144, 'max_bin': 266}. Best is trial 34 with value: 25549.00447025088.
# [I 2025-11-06 10:08:13,812] Trial 36 finished with value: 27591.858370891627 and parameters: {'num_leaves': 86, 'max_depth': 6, 'learning_rate': 0.008527389570561844, 'n_estimators': 3882, 'feature_fraction': 0.7311921695029391, 'bagging_fraction': 0.5417431674342154, 'bagging_freq': 3, 'min_child_samples': 15, 'min_child_weight': 0.0002168199302627842, 'lambda_l1': 0.34391048779098493, 'lambda_l2': 0.11284677066551885, 'min_split_gain': 0.010074108186868925, 'max_bin': 275}. Best is trial 34 with value: 25549.00447025088.
# [I 2025-11-06 10:09:19,499] Trial 37 finished with value: 25711.84880577757 and parameters: {'num_leaves': 122, 'max_depth': 8, 'learning_rate': 0.01722582042806242, 'n_estimators': 5767, 'feature_fraction': 0.6476031692251799, 'bagging_fraction': 0.5849404535375595, 'bagging_freq': 5, 'min_child_samples': 17, 'min_child_weight': 0.00014886467341529699, 'lambda_l1': 0.003888683662267134, 'lambda_l2': 0.6171131100638143, 'min_split_gain': 0.0058170657961570844, 'max_bin': 250}. Best is trial 34 with value: 25549.00447025088.
# [I 2025-11-06 10:09:56,519] Trial 38 finished with value: 25802.071869051157 and parameters: {'num_leaves': 78, 'max_depth': 10, 'learning_rate': 0.029749424578431848, 'n_estimators': 5313, 'feature_fraction': 0.6084481505508901, 'bagging_fraction': 0.5111054440286057, 'bagging_freq': 3, 'min_child_samples': 11, 'min_child_weight': 0.00010589214339833023, 'lambda_l1': 0.17218472898794074, 'lambda_l2': 0.8074323458689201, 'min_split_gain': 0.013993447094832061, 'max_bin': 287}. Best is trial 34 with value: 25549.00447025088.
# [I 2025-11-06 10:10:41,882] Trial 39 finished with value: 26848.0605392599 and parameters: {'num_leaves': 132, 'max_depth': 9, 'learning_rate': 0.006340220707662831, 'n_estimators': 2924, 'feature_fraction': 0.7752822721699641, 'bagging_fraction': 0.5428435404753901, 'bagging_freq': 1, 'min_child_samples': 14, 'min_child_weight': 0.00036630455022958907, 'lambda_l1': 0.46111314941952464, 'lambda_l2': 0.4429209217193676, 'min_split_gain': 0.011932669202117411, 'max_bin': 247}. Best is trial 34 with value: 25549.00447025088.
# [I 2025-11-06 10:11:20,342] Trial 40 finished with value: 26033.041208482846 and parameters: {'num_leaves': 103, 'max_depth': 12, 'learning_rate': 0.015706781550794316, 'n_estimators': 2416, 'feature_fraction': 0.6898685328144516, 'bagging_fraction': 0.5886080636635339, 'bagging_freq': 4, 'min_child_samples': 17, 'min_child_weight': 0.00026682450733611624, 'lambda_l1': 0.13729860423254792, 'lambda_l2': 0.6906753199022512, 'min_split_gain': 0.02002679308444385, 'max_bin': 264}. Best is trial 34 with value: 25549.00447025088.
# [I 2025-11-06 10:12:36,939] Trial 41 finished with value: 25573.234938797323 and parameters: {'num_leaves': 139, 'max_depth': 15, 'learning_rate': 0.013533827799728487, 'n_estimators': 5720, 'feature_fraction': 0.5475024150500125, 'bagging_fraction': 0.6987767615479682, 'bagging_freq': 2, 'min_child_samples': 19, 'min_child_weight': 0.00047250768317746013, 'lambda_l1': 1.17058628945927, 'lambda_l2': 1.1973701182194836, 'min_split_gain': 0.023192563466898984, 'max_bin': 255}. Best is trial 34 with value: 25549.00447025088.
# [I 2025-11-06 10:14:01,870] Trial 42 finished with value: 25504.898350468586 and parameters: {'num_leaves': 146, 'max_depth': 14, 'learning_rate': 0.011607983817918428, 'n_estimators': 5837, 'feature_fraction': 0.5126101821261263, 'bagging_fraction': 0.631800444719957, 'bagging_freq': 2, 'min_child_samples': 19, 'min_child_weight': 0.0001889371359423458, 'lambda_l1': 1.249188450957309, 'lambda_l2': 0.9968859250869782, 'min_split_gain': 0.01623768958450385, 'max_bin': 256}. Best is trial 42 with value: 25504.898350468586.
# [I 2025-11-06 10:15:33,016] Trial 43 finished with value: 25501.17975270917 and parameters: {'num_leaves': 138, 'max_depth': 13, 'learning_rate': 0.01103241775043822, 'n_estimators': 5813, 'feature_fraction': 0.5001990456914002, 'bagging_fraction': 0.6283080806005326, 'bagging_freq': 2, 'min_child_samples': 19, 'min_child_weight': 0.00017592987220515133, 'lambda_l1': 1.2276301129487117, 'lambda_l2': 0.9541333469498767, 'min_split_gain': 0.01517678855734771, 'max_bin': 252}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:16:59,347] Trial 44 finished with value: 25509.022218306567 and parameters: {'num_leaves': 130, 'max_depth': 11, 'learning_rate': 0.01136946110594962, 'n_estimators': 5852, 'feature_fraction': 0.5139341070073246, 'bagging_fraction': 0.6301596669107015, 'bagging_freq': 3, 'min_child_samples': 16, 'min_child_weight': 0.00018189010118729732, 'lambda_l1': 1.3252101299657657, 'lambda_l2': 0.9881964776675616, 'min_split_gain': 0.015190328043604049, 'max_bin': 238}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:18:51,823] Trial 45 finished with value: 25653.535643994474 and parameters: {'num_leaves': 120, 'max_depth': -1, 'learning_rate': 0.01116991567511854, 'n_estimators': 5825, 'feature_fraction': 0.5002509559403832, 'bagging_fraction': 0.6244744372007258, 'bagging_freq': 3, 'min_child_samples': 15, 'min_child_weight': 0.00016629647116489583, 'lambda_l1': 1.407585523871132, 'lambda_l2': 0.972511398232016, 'min_split_gain': 0.014689104598143078, 'max_bin': 239}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:20:14,133] Trial 46 finished with value: 25519.386338371918 and parameters: {'num_leaves': 129, 'max_depth': 11, 'learning_rate': 0.009599386022022203, 'n_estimators': 5449, 'feature_fraction': 0.5175828328888376, 'bagging_fraction': 0.6529870807164164, 'bagging_freq': 3, 'min_child_samples': 19, 'min_child_weight': 0.00012353589441241458, 'lambda_l1': 1.3200832475833888, 'lambda_l2': 0.7638019855516783, 'min_split_gain': 0.006599170691962582, 'max_bin': 248}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:21:31,711] Trial 47 finished with value: 25566.92029459671 and parameters: {'num_leaves': 124, 'max_depth': 10, 'learning_rate': 0.008511376839616535, 'n_estimators': 5465, 'feature_fraction': 0.5161441436829155, 'bagging_fraction': 0.64048915898946, 'bagging_freq': 3, 'min_child_samples': 21, 'min_child_weight': 0.00011999770232353196, 'lambda_l1': 1.3022969206842303, 'lambda_l2': 0.7994363206387134, 'min_split_gain': 0.00313089407016425, 'max_bin': 253}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:22:48,284] Trial 48 finished with value: 25564.20986019233 and parameters: {'num_leaves': 117, 'max_depth': 11, 'learning_rate': 0.010251454840950254, 'n_estimators': 5096, 'feature_fraction': 0.5169158200528955, 'bagging_fraction': 0.6670052484045248, 'bagging_freq': 3, 'min_child_samples': 16, 'min_child_weight': 0.00014518506482609077, 'lambda_l1': 1.601851726810505, 'lambda_l2': 0.5541797867037552, 'min_split_gain': 0.008491714639692945, 'max_bin': 246}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:24:01,903] Trial 49 finished with value: 25607.92267954849 and parameters: {'num_leaves': 130, 'max_depth': 9, 'learning_rate': 0.011574547615980318, 'n_estimators': 5404, 'feature_fraction': 0.5847145503790205, 'bagging_fraction': 0.635333840521489, 'bagging_freq': 4, 'min_child_samples': 18, 'min_child_weight': 0.00018802368588470117, 'lambda_l1': 1.5383100960540381, 'lambda_l2': 1.0264455397468066, 'min_split_gain': 0.006023439441133519, 'max_bin': 249}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:25:53,237] Trial 50 finished with value: 25585.272458634965 and parameters: {'num_leaves': 147, 'max_depth': 13, 'learning_rate': 0.006337808243752397, 'n_estimators': 5871, 'feature_fraction': 0.5627984857520212, 'bagging_fraction': 0.614843273810296, 'bagging_freq': 3, 'min_child_samples': 14, 'min_child_weight': 0.00010416855429013692, 'lambda_l1': 1.2740347800388294, 'lambda_l2': 0.7114241956821248, 'min_split_gain': 0.012015400148568599, 'max_bin': 259}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:27:34,025] Trial 51 finished with value: 25530.963954551407 and parameters: {'num_leaves': 129, 'max_depth': 12, 'learning_rate': 0.010142388761254336, 'n_estimators': 5958, 'feature_fraction': 0.5010892326043758, 'bagging_fraction': 0.694635849016999, 'bagging_freq': 2, 'min_child_samples': 19, 'min_child_weight': 0.0002827379293979623, 'lambda_l1': 1.1843708558620927, 'lambda_l2': 0.8915330657859404, 'min_split_gain': 0.015589222753503022, 'max_bin': 242}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:29:14,934] Trial 52 finished with value: 25511.550197107426 and parameters: {'num_leaves': 139, 'max_depth': 12, 'learning_rate': 0.009647825716398467, 'n_estimators': 5711, 'feature_fraction': 0.517222866892698, 'bagging_fraction': 0.6941941626036615, 'bagging_freq': 2, 'min_child_samples': 21, 'min_child_weight': 0.00019409359467248966, 'lambda_l1': 1.1731081283897051, 'lambda_l2': 0.9328032079178118, 'min_split_gain': 0.0162534728480352, 'max_bin': 230}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:30:44,534] Trial 53 finished with value: 25569.786230275728 and parameters: {'num_leaves': 139, 'max_depth': 12, 'learning_rate': 0.00788461486802512, 'n_estimators': 5155, 'feature_fraction': 0.5143721391022575, 'bagging_fraction': 0.697194301325021, 'bagging_freq': 2, 'min_child_samples': 21, 'min_child_weight': 0.0002695669446552538, 'lambda_l1': 1.2180538121868756, 'lambda_l2': 0.9329843659912836, 'min_split_gain': 0.016570485461701204, 'max_bin': 242}. Best is trial 43 with value: 25501.17975270917.
# [I 2025-11-06 10:32:18,115] Trial 54 finished with value: 25491.540471142274 and parameters: {'num_leaves': 140, 'max_depth': 12, 'learning_rate': 0.009827217299756193, 'n_estimators': 5644, 'feature_fraction': 0.5320231689461608, 'bagging_fraction': 0.663752394504896, 'bagging_freq': 2, 'min_child_samples': 23, 'min_child_weight': 0.0001946545664299833, 'lambda_l1': 0.9710691197429211, 'lambda_l2': 0.8262698481098683, 'min_split_gain': 0.04555528789067391, 'max_bin': 230}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:33:42,790] Trial 55 finished with value: 25512.095122335548 and parameters: {'num_leaves': 141, 'max_depth': 10, 'learning_rate': 0.00937748984493565, 'n_estimators': 5615, 'feature_fraction': 0.5318914399663648, 'bagging_fraction': 0.6610432475330601, 'bagging_freq': 2, 'min_child_samples': 23, 'min_child_weight': 0.0001969933090541426, 'lambda_l1': 0.9701253477189533, 'lambda_l2': 0.8052993975729911, 'min_split_gain': 0.04607878960743272, 'max_bin': 230}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:35:24,007] Trial 56 finished with value: 25554.284195034346 and parameters: {'num_leaves': 141, 'max_depth': 13, 'learning_rate': 0.006826434849107628, 'n_estimators': 5669, 'feature_fraction': 0.537591406078759, 'bagging_fraction': 0.6662984712902134, 'bagging_freq': 2, 'min_child_samples': 23, 'min_child_weight': 0.005359642250355741, 'lambda_l1': 0.9527142143000014, 'lambda_l2': 0.8230441791198853, 'min_split_gain': 0.04747428483413722, 'max_bin': 230}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:36:24,327] Trial 57 finished with value: 25841.590009403084 and parameters: {'num_leaves': 148, 'max_depth': 8, 'learning_rate': 0.008016771893531338, 'n_estimators': 4980, 'feature_fraction': 0.5530405891834185, 'bagging_fraction': 0.622525740072244, 'bagging_freq': 2, 'min_child_samples': 23, 'min_child_weight': 0.00018453950265346624, 'lambda_l1': 1.0478400466048616, 'lambda_l2': 1.0717655166692288, 'min_split_gain': 0.041869481013489286, 'max_bin': 222}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:37:33,951] Trial 58 finished with value: 25652.040549698682 and parameters: {'num_leaves': 91, 'max_depth': 10, 'learning_rate': 0.00902589283070056, 'n_estimators': 5580, 'feature_fraction': 0.5322725350502173, 'bagging_fraction': 0.599431343808622, 'bagging_freq': 2, 'min_child_samples': 24, 'min_child_weight': 0.00019425712829960337, 'lambda_l1': 1.4547239703551185, 'lambda_l2': 0.9555266579262167, 'min_split_gain': 0.04717782760961016, 'max_bin': 215}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:39:22,262] Trial 59 finished with value: 26281.443714000485 and parameters: {'num_leaves': 150, 'max_depth': 12, 'learning_rate': 0.011604609448096829, 'n_estimators': 5815, 'feature_fraction': 0.8594927751894322, 'bagging_fraction': 0.6381191308705431, 'bagging_freq': 2, 'min_child_samples': 22, 'min_child_weight': 0.00031269849681672, 'lambda_l1': 0.9891588793404464, 'lambda_l2': 1.2598626812532587, 'min_split_gain': 0.04996396041677475, 'max_bin': 230}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:39:41,703] Trial 60 finished with value: 35812.22472501597 and parameters: {'num_leaves': 136, 'max_depth': 2, 'learning_rate': 0.010176449623547938, 'n_estimators': 5359, 'feature_fraction': 0.8240633515540688, 'bagging_fraction': 0.6853516749402536, 'bagging_freq': 2, 'min_child_samples': 25, 'min_child_weight': 0.00023845270377111, 'lambda_l1': 1.0987651712867477, 'lambda_l2': 1.1397456500434227, 'min_split_gain': 0.041718536456185965, 'max_bin': 210}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:41:07,744] Trial 61 finished with value: 25507.612672357867 and parameters: {'num_leaves': 139, 'max_depth': 11, 'learning_rate': 0.009492506151880954, 'n_estimators': 5439, 'feature_fraction': 0.5138317634371392, 'bagging_fraction': 0.654050691426987, 'bagging_freq': 2, 'min_child_samples': 22, 'min_child_weight': 0.00015939003673962667, 'lambda_l1': 1.363832621022493, 'lambda_l2': 0.7895115976560497, 'min_split_gain': 0.039083433631767056, 'max_bin': 224}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:42:44,982] Trial 62 finished with value: 25504.669177966385 and parameters: {'num_leaves': 142, 'max_depth': 13, 'learning_rate': 0.009204675204703671, 'n_estimators': 5634, 'feature_fraction': 0.5335009519649261, 'bagging_fraction': 0.663053480316497, 'bagging_freq': 2, 'min_child_samples': 22, 'min_child_weight': 0.00016700528227579255, 'lambda_l1': 1.368597153007663, 'lambda_l2': 0.8567910820269001, 'min_split_gain': 0.0451185753895474, 'max_bin': 221}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:44:20,103] Trial 63 finished with value: 25591.395213860087 and parameters: {'num_leaves': 138, 'max_depth': 13, 'learning_rate': 0.0070167148764486076, 'n_estimators': 5197, 'feature_fraction': 0.514377908007557, 'bagging_fraction': 0.7163791065218379, 'bagging_freq': 2, 'min_child_samples': 22, 'min_child_weight': 0.00015860786560554623, 'lambda_l1': 1.376793192208082, 'lambda_l2': 1.0341579577646587, 'min_split_gain': 0.03863831070609369, 'max_bin': 225}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:46:05,482] Trial 64 finished with value: 25506.684140894413 and parameters: {'num_leaves': 146, 'max_depth': 14, 'learning_rate': 0.008062802834094208, 'n_estimators': 5714, 'feature_fraction': 0.5408280442710842, 'bagging_fraction': 0.6828304667023196, 'bagging_freq': 1, 'min_child_samples': 21, 'min_child_weight': 0.00023758551728599416, 'lambda_l1': 1.4896154439317857, 'lambda_l2': 0.8562538402631784, 'min_split_gain': 0.043537992730128004, 'max_bin': 236}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:47:57,676] Trial 65 finished with value: 25560.191747984965 and parameters: {'num_leaves': 147, 'max_depth': 14, 'learning_rate': 0.005838563123399227, 'n_estimators': 5840, 'feature_fraction': 0.5579231085489428, 'bagging_fraction': 0.6751740887512186, 'bagging_freq': 1, 'min_child_samples': 24, 'min_child_weight': 0.00011469223016984632, 'lambda_l1': 1.7635502251749076, 'lambda_l2': 0.8662546288365616, 'min_split_gain': 0.045056694012987154, 'max_bin': 236}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:49:35,687] Trial 66 finished with value: 25501.284746198526 and parameters: {'num_leaves': 144, 'max_depth': 13, 'learning_rate': 0.007895571370229807, 'n_estimators': 5500, 'feature_fraction': 0.5412708199141886, 'bagging_fraction': 0.6457394414723923, 'bagging_freq': 1, 'min_child_samples': 20, 'min_child_weight': 0.00016839365788765944, 'lambda_l1': 1.4741108899770377, 'lambda_l2': 0.6457974439842454, 'min_split_gain': 0.03913550264937358, 'max_bin': 221}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:51:03,617] Trial 67 finished with value: 25619.594849012905 and parameters: {'num_leaves': 143, 'max_depth': 14, 'learning_rate': 0.008173092352464571, 'n_estimators': 4621, 'feature_fraction': 0.592559815158305, 'bagging_fraction': 0.6476145763069816, 'bagging_freq': 1, 'min_child_samples': 22, 'min_child_weight': 0.009628132852793875, 'lambda_l1': 1.5077144016622381, 'lambda_l2': 0.49938537668314315, 'min_split_gain': 0.03802441239839945, 'max_bin': 219}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:52:41,327] Trial 68 finished with value: 25531.535606089896 and parameters: {'num_leaves': 145, 'max_depth': 13, 'learning_rate': 0.007261022376734762, 'n_estimators': 5454, 'feature_fraction': 0.54247555368923, 'bagging_fraction': 0.6586825473227041, 'bagging_freq': 1, 'min_child_samples': 20, 'min_child_weight': 0.00015607659403554783, 'lambda_l1': 1.4822920644977675, 'lambda_l2': 0.6567075291748001, 'min_split_gain': 0.04277740804688364, 'max_bin': 203}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:54:23,739] Trial 69 finished with value: 25647.220586827825 and parameters: {'num_leaves': 133, 'max_depth': 15, 'learning_rate': 0.005988398771371839, 'n_estimators': 5533, 'feature_fraction': 0.5623315506372513, 'bagging_fraction': 0.6157572214960944, 'bagging_freq': 1, 'min_child_samples': 21, 'min_child_weight': 0.00025035945197270706, 'lambda_l1': 1.704036686576213, 'lambda_l2': 0.2268693700395904, 'min_split_gain': 0.04067215489476015, 'max_bin': 223}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:55:42,789] Trial 70 finished with value: 25538.36250609533 and parameters: {'num_leaves': 147, 'max_depth': 13, 'learning_rate': 0.0146773093360186, 'n_estimators': 4853, 'feature_fraction': 0.5399841457469629, 'bagging_fraction': 0.6807141968175706, 'bagging_freq': 1, 'min_child_samples': 26, 'min_child_weight': 0.0003178210616287995, 'lambda_l1': 1.5750130426945697, 'lambda_l2': 0.7432142165862818, 'min_split_gain': 0.04469456218869456, 'max_bin': 214}. Best is trial 54 with value: 25491.540471142274.
# [I 2025-11-06 10:57:18,137] Trial 71 finished with value: 25489.08148832475 and parameters: {'num_leaves': 142, 'max_depth': 14, 'learning_rate': 0.010651792585637322, 'n_estimators': 5647, 'feature_fraction': 0.5291493952412648, 'bagging_fraction': 0.6307388984819162, 'bagging_freq': 2, 'min_child_samples': 20, 'min_child_weight': 0.00016655270710498447, 'lambda_l1': 1.3749990132526004, 'lambda_l2': 1.0612305481625977, 'min_split_gain': 0.03725000198787291, 'max_bin': 209}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 10:58:59,193] Trial 72 finished with value: 25500.932575906787 and parameters: {'num_leaves': 142, 'max_depth': 14, 'learning_rate': 0.008888614082416018, 'n_estimators': 5649, 'feature_fraction': 0.5304203201192648, 'bagging_fraction': 0.6437823355274153, 'bagging_freq': 2, 'min_child_samples': 20, 'min_child_weight': 0.00013265423307351628, 'lambda_l1': 1.3539159866726036, 'lambda_l2': 0.8685986664729204, 'min_split_gain': 0.03681134601856131, 'max_bin': 212}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:00:38,820] Trial 73 finished with value: 25490.665389515492 and parameters: {'num_leaves': 142, 'max_depth': 14, 'learning_rate': 0.007619198755181874, 'n_estimators': 5627, 'feature_fraction': 0.5262630321937652, 'bagging_fraction': 0.5960313667772993, 'bagging_freq': 1, 'min_child_samples': 20, 'min_child_weight': 0.00013337488487454803, 'lambda_l1': 1.2690864500529673, 'lambda_l2': 0.8557526495343295, 'min_split_gain': 0.03717320993512279, 'max_bin': 208}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:02:32,290] Trial 74 finished with value: 26223.31293230664 and parameters: {'num_leaves': 143, 'max_depth': 15, 'learning_rate': 0.008906298557691051, 'n_estimators': 5258, 'feature_fraction': 0.8994561457577134, 'bagging_fraction': 0.5903026867314431, 'bagging_freq': 1, 'min_child_samples': 20, 'min_child_weight': 0.00013410024934472397, 'lambda_l1': 1.227538686213844, 'lambda_l2': 1.0508187886612657, 'min_split_gain': 0.036356388400955675, 'max_bin': 207}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:04:10,310] Trial 75 finished with value: 25521.944473744585 and parameters: {'num_leaves': 136, 'max_depth': 14, 'learning_rate': 0.007506965870047732, 'n_estimators': 5623, 'feature_fraction': 0.5246273982397426, 'bagging_fraction': 0.6417875999346921, 'bagging_freq': 2, 'min_child_samples': 19, 'min_child_weight': 0.00010318280936542462, 'lambda_l1': 1.4201653992300476, 'lambda_l2': 1.1108346563953257, 'min_split_gain': 0.03211776953543571, 'max_bin': 211}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:05:35,802] Trial 76 finished with value: 25571.21982318664 and parameters: {'num_leaves': 150, 'max_depth': 15, 'learning_rate': 0.010778855794327195, 'n_estimators': 5344, 'feature_fraction': 0.5676806387587704, 'bagging_fraction': 0.6080304002927195, 'bagging_freq': 2, 'min_child_samples': 18, 'min_child_weight': 0.00021259072264349818, 'lambda_l1': 1.1306605512868226, 'lambda_l2': 0.6371778812232833, 'min_split_gain': 0.03657466428815181, 'max_bin': 200}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:06:53,942] Trial 77 finished with value: 25513.790199012972 and parameters: {'num_leaves': 142, 'max_depth': 14, 'learning_rate': 0.01239129537427469, 'n_estimators': 5910, 'feature_fraction': 0.5263187781635895, 'bagging_fraction': 0.6247793886542852, 'bagging_freq': 1, 'min_child_samples': 19, 'min_child_weight': 0.0001320820449846493, 'lambda_l1': 1.2371819497704195, 'lambda_l2': 0.9157646607696145, 'min_split_gain': 0.03363427420312265, 'max_bin': 206}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:07:26,202] Trial 78 finished with value: 25913.10772545809 and parameters: {'num_leaves': 63, 'max_depth': 13, 'learning_rate': 0.04700952610485248, 'n_estimators': 5551, 'feature_fraction': 0.5507150538621247, 'bagging_fraction': 0.6049576984975528, 'bagging_freq': 2, 'min_child_samples': 20, 'min_child_weight': 0.00016647309379799055, 'lambda_l1': 0.887883296729361, 'lambda_l2': 0.5316338900190011, 'min_split_gain': 0.040071900562208065, 'max_bin': 218}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:08:50,183] Trial 79 finished with value: 25518.56325001481 and parameters: {'num_leaves': 126, 'max_depth': 15, 'learning_rate': 0.00857799301557004, 'n_estimators': 5022, 'feature_fraction': 0.5063711611077159, 'bagging_fraction': 0.554702106025693, 'bagging_freq': 1, 'min_child_samples': 20, 'min_child_weight': 0.00011991165883924504, 'lambda_l1': 1.353086987582672, 'lambda_l2': 1.2528359110938885, 'min_split_gain': 0.030357645833698432, 'max_bin': 215}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:10:33,842] Trial 80 finished with value: 25683.761887156797 and parameters: {'num_leaves': 133, 'max_depth': 14, 'learning_rate': 0.00567612504962798, 'n_estimators': 5641, 'feature_fraction': 0.5843354597253981, 'bagging_fraction': 0.6429961147064974, 'bagging_freq': 2, 'min_child_samples': 18, 'min_child_weight': 0.0009212958545990162, 'lambda_l1': 1.6583496852433466, 'lambda_l2': 0.8547617024951101, 'min_split_gain': 0.03615491043778491, 'max_bin': 209}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:12:16,961] Trial 81 finished with value: 25505.802720272943 and parameters: {'num_leaves': 146, 'max_depth': 14, 'learning_rate': 0.007891451171990445, 'n_estimators': 5702, 'feature_fraction': 0.5372674550414323, 'bagging_fraction': 0.6725212808592953, 'bagging_freq': 1, 'min_child_samples': 21, 'min_child_weight': 0.00014405072251875116, 'lambda_l1': 1.4411265467433498, 'lambda_l2': 0.8607577750740648, 'min_split_gain': 0.04436542128642255, 'max_bin': 204}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:13:56,378] Trial 82 finished with value: 25537.37534863473 and parameters: {'num_leaves': 137, 'max_depth': 13, 'learning_rate': 0.006880248491253913, 'n_estimators': 5776, 'feature_fraction': 0.5345196109022319, 'bagging_fraction': 0.6709660053301407, 'bagging_freq': 1, 'min_child_samples': 21, 'min_child_weight': 0.00014583578598616987, 'lambda_l1': 1.437399900518103, 'lambda_l2': 0.9688479473809749, 'min_split_gain': 0.04916933810481374, 'max_bin': 205}. Best is trial 71 with value: 25489.08148832475.
# [I 2025-11-06 11:15:38,785] Trial 83 finished with value: 25472.14471234489 and parameters: {'num_leaves': 145, 'max_depth': 14, 'learning_rate': 0.0076215673297352435, 'n_estimators': 5899, 'feature_fraction': 0.5495114801027534, 'bagging_fraction': 0.5969191668207082, 'bagging_freq': 1, 'min_child_samples': 20, 'min_child_weight': 0.00021290524886950817, 'lambda_l1': 1.5277193564719531, 'lambda_l2': 0.7375569473926705, 'min_split_gain': 0.037426126324434816, 'max_bin': 214}. Best is trial 83 with value: 25472.14471234489.
# [I 2025-11-06 11:17:08,727] Trial 84 finished with value: 25484.31803922151 and parameters: {'num_leaves': 142, 'max_depth': 14, 'learning_rate': 0.01062239571344101, 'n_estimators': 5870, 'feature_fraction': 0.5247124275984684, 'bagging_fraction': 0.5948238327173321, 'bagging_freq': 1, 'min_child_samples': 18, 'min_child_weight': 0.00020206711900556376, 'lambda_l1': 1.2648205185710255, 'lambda_l2': 0.5806026900011143, 'min_split_gain': 0.0340795276999664, 'max_bin': 212}. Best is trial 83 with value: 25472.14471234489.
# [I 2025-11-06 11:18:42,405] Trial 85 finished with value: 25483.77479988341 and parameters: {'num_leaves': 142, 'max_depth': 15, 'learning_rate': 0.010533809038366789, 'n_estimators': 5921, 'feature_fraction': 0.5529713913733466, 'bagging_fraction': 0.5782614705260439, 'bagging_freq': 1, 'min_child_samples': 17, 'min_child_weight': 0.0002134728327094824, 'lambda_l1': 1.5431342551938207, 'lambda_l2': 0.6060893583816886, 'min_split_gain': 0.034357850756354655, 'max_bin': 213}. Best is trial 83 with value: 25472.14471234489.
# [I 2025-11-06 11:20:16,419] Trial 86 finished with value: 25485.501417811978 and parameters: {'num_leaves': 134, 'max_depth': 15, 'learning_rate': 0.01073738705030063, 'n_estimators': 5912, 'feature_fraction': 0.5552891544377098, 'bagging_fraction': 0.5805319154018577, 'bagging_freq': 1, 'min_child_samples': 17, 'min_child_weight': 0.000366010108414903, 'lambda_l1': 1.5304333782135968, 'lambda_l2': 0.42499935567355085, 'min_split_gain': 0.03411940967489681, 'max_bin': 212}. Best is trial 83 with value: 25472.14471234489.
# [I 2025-11-06 11:21:47,346] Trial 87 finished with value: 25569.53328547352 and parameters: {'num_leaves': 134, 'max_depth': 15, 'learning_rate': 0.010272406419599527, 'n_estimators': 5896, 'feature_fraction': 0.5739085623779533, 'bagging_fraction': 0.5798537621043041, 'bagging_freq': 1, 'min_child_samples': 17, 'min_child_weight': 0.0004039818502693416, 'lambda_l1': 1.543511855175294, 'lambda_l2': 0.373784335447771, 'min_split_gain': 0.03394524508345669, 'max_bin': 213}. Best is trial 83 with value: 25472.14471234489.
# [I 2025-11-06 11:23:08,830] Trial 88 finished with value: 25511.450411292008 and parameters: {'num_leaves': 140, 'max_depth': 15, 'learning_rate': 0.010934527331646656, 'n_estimators': 5771, 'feature_fraction': 0.5526281484703264, 'bagging_fraction': 0.5949016926995113, 'bagging_freq': 1, 'min_child_samples': 17, 'min_child_weight': 0.00021208174772240342, 'lambda_l1': 1.7398723674023417, 'lambda_l2': 0.2744205079131486, 'min_split_gain': 0.032628583550679005, 'max_bin': 217}. Best is trial 83 with value: 25472.14471234489.
# [I 2025-11-06 11:25:07,118] Trial 89 finished with value: 26168.189260460396 and parameters: {'num_leaves': 149, 'max_depth': 15, 'learning_rate': 0.009809808539552246, 'n_estimators': 5983, 'feature_fraction': 0.8760341639902888, 'bagging_fraction': 0.5553302054543708, 'bagging_freq': 1, 'min_child_samples': 18, 'min_child_weight': 0.00027792086789338056, 'lambda_l1': 1.6370103679444874, 'lambda_l2': 0.4393992652881227, 'min_split_gain': 0.030312447514249004, 'max_bin': 208}. Best is trial 83 with value: 25472.14471234489.
# [I 2025-11-06 11:26:34,163] Trial 90 finished with value: 25592.988843073428 and parameters: {'num_leaves': 110, 'max_depth': 15, 'learning_rate': 0.012478536775678362, 'n_estimators': 5911, 'feature_fraction': 0.5649830858403521, 'bagging_fraction': 0.5767584309336912, 'bagging_freq': 1, 'min_child_samples': 17, 'min_child_weight': 0.00035263822081816546, 'lambda_l1': 1.050077714789267, 'lambda_l2': 0.5684804338333754, 'min_split_gain': 0.035195743752356436, 'max_bin': 211}. Best is trial 83 with value: 25472.14471234489.
# [I 2025-11-06 11:28:16,512] Trial 91 finished with value: 25466.907650052064 and parameters: {'num_leaves': 144, 'max_depth': 14, 'learning_rate': 0.008658602567233812, 'n_estimators': 5993, 'feature_fraction': 0.5239430389720078, 'bagging_fraction': 0.6139928094104088, 'bagging_freq': 1, 'min_child_samples': 19, 'min_child_weight': 0.00011466859733175063, 'lambda_l1': 1.301666791297003, 'lambda_l2': 0.7313797900302192, 'min_split_gain': 0.03728398246405323, 'max_bin': 200}. Best is trial 91 with value: 25466.907650052064.
# [I 2025-11-06 11:29:55,105] Trial 92 finished with value: 25471.868763703005 and parameters: {'num_leaves': 137, 'max_depth': 14, 'learning_rate': 0.008636175238125285, 'n_estimators': 5998, 'feature_fraction': 0.5243798498255001, 'bagging_fraction': 0.5654838462286175, 'bagging_freq': 1, 'min_child_samples': 18, 'min_child_weight': 0.0001119643953108655, 'lambda_l1': 1.2858125339306135, 'lambda_l2': 0.48172337811710825, 'min_split_gain': 0.03758131861996162, 'max_bin': 200}. Best is trial 91 with value: 25466.907650052064.
# [I 2025-11-06 11:30:30,974] Trial 93 finished with value: 26159.491688187758 and parameters: {'num_leaves': 136, 'max_depth': 14, 'learning_rate': 0.008316230574584044, 'n_estimators': 2039, 'feature_fraction': 0.527747520376137, 'bagging_fraction': 0.5750729685973849, 'bagging_freq': 1, 'min_child_samples': 17, 'min_child_weight': 0.00011552363379757151, 'lambda_l1': 1.294969569759352, 'lambda_l2': 0.47444626531599876, 'min_split_gain': 0.0375906438855277, 'max_bin': 202}. Best is trial 91 with value: 25466.907650052064.
# [I 2025-11-06 11:32:12,063] Trial 94 finished with value: 25457.89832384576 and parameters: {'num_leaves': 142, 'max_depth': 14, 'learning_rate': 0.00878105259079402, 'n_estimators': 5992, 'feature_fraction': 0.5503534154978461, 'bagging_fraction': 0.5640646616459816, 'bagging_freq': 1, 'min_child_samples': 18, 'min_child_weight': 0.0012706241134137263, 'lambda_l1': 1.545571553527497, 'lambda_l2': 0.6854897469160511, 'min_split_gain': 0.03709289827024509, 'max_bin': 201}. Best is trial 94 with value: 25457.89832384576.
# [I 2025-11-06 11:33:53,929] Trial 95 finished with value: 25537.026369645548 and parameters: {'num_leaves': 132, 'max_depth': 15, 'learning_rate': 0.00763196047340166, 'n_estimators': 5994, 'feature_fraction': 0.5987852694380544, 'bagging_fraction': 0.5268991166899, 'bagging_freq': 1, 'min_child_samples': 18, 'min_child_weight': 0.0013283167463069157, 'lambda_l1': 1.5687584320837082, 'lambda_l2': 0.5841023396494152, 'min_split_gain': 0.03516686341472776, 'max_bin': 200}. Best is trial 94 with value: 25457.89832384576.
# [I 2025-11-06 11:35:33,777] Trial 96 finished with value: 25457.664308262956 and parameters: {'num_leaves': 144, 'max_depth': 14, 'learning_rate': 0.007272698914248853, 'n_estimators': 5895, 'feature_fraction': 0.5494699263850129, 'bagging_fraction': 0.5451546623033238, 'bagging_freq': 1, 'min_child_samples': 15, 'min_child_weight': 0.002158697533609497, 'lambda_l1': 1.668389475448569, 'lambda_l2': 0.41010045543664, 'min_split_gain': 0.04022193440027789, 'max_bin': 206}. Best is trial 96 with value: 25457.664308262956.
# [I 2025-11-06 11:37:19,346] Trial 97 finished with value: 25528.852979383217 and parameters: {'num_leaves': 144, 'max_depth': 15, 'learning_rate': 0.007260865745410266, 'n_estimators': 5900, 'feature_fraction': 0.5596729120496559, 'bagging_fraction': 0.540620247380617, 'bagging_freq': 1, 'min_child_samples': 15, 'min_child_weight': 0.0021255572023439777, 'lambda_l1': 1.6703015883899583, 'lambda_l2': 0.2904599509789876, 'min_split_gain': 0.0401040757547889, 'max_bin': 202}. Best is trial 96 with value: 25457.664308262956.
# [I 2025-11-06 11:39:04,168] Trial 98 finished with value: 25556.66617507735 and parameters: {'num_leaves': 148, 'max_depth': 14, 'learning_rate': 0.006495745602552032, 'n_estimators': 5781, 'feature_fraction': 0.5789762567415627, 'bagging_fraction': 0.5641558708919612, 'bagging_freq': 1, 'min_child_samples': 16, 'min_child_weight': 0.001517957006896506, 'lambda_l1': 1.8365723821165523, 'lambda_l2': 0.42249744609829687, 'min_split_gain': 0.034015927863445754, 'max_bin': 207}. Best is trial 96 with value: 25457.664308262956.
# [I 2025-11-06 11:40:36,826] Trial 99 finished with value: 25619.461853488756 and parameters: {'num_leaves': 137, 'max_depth': 14, 'learning_rate': 0.010581233795565892, 'n_estimators': 5888, 'feature_fraction': 0.6327284709754774, 'bagging_fraction': 0.5507659534171678, 'bagging_freq': 1, 'min_child_samples': 18, 'min_child_weight': 0.0037894972860965403, 'lambda_l1': 1.603168723441024, 'lambda_l2': 0.5331834742389562, 'min_split_gain': 0.03119865429143657, 'max_bin': 205}. Best is trial 96 with value: 25457.664308262956.

# %%
# Print optimization results
print("\n" + "="*80)
print("Optimization Complete!")
print("="*80)
# Out:
# ================================================================================
# Optimization Complete!
# ================================================================================

# %%
print(f"\nBest CV RMSE: {study.best_value:,.2f}")
print(f"Number of trials: {len(study.trials)}")
# Out:
# Best CV RMSE: 25,457.66
# Number of trials: 100

# %%
print("\nBest hyperparameters:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
# Out:
# Best hyperparameters:
#   num_leaves: 144
#   max_depth: 14
#   learning_rate: 0.007272698914248853
#   n_estimators: 5895
#   feature_fraction: 0.5494699263850129
#   bagging_fraction: 0.5451546623033238
#   bagging_freq: 1
#   min_child_samples: 15
#   min_child_weight: 0.002158697533609497
#   lambda_l1: 1.668389475448569
#   lambda_l2: 0.41010045543664
#   min_split_gain: 0.04022193440027789
#   max_bin: 206

# %%
# Save optimization results
study_df = study.trials_dataframe()
study_df.to_csv('optuna_study_results.csv', index=False)
print("\nOptimization history saved to: optuna_study_results.csv")
# Out:
# Optimization history saved to: optuna_study_results.csv

# %%
# Train final model with best parameters
print("\n" + "="*80)
print("Training Final Model with Best Parameters (5-Fold CV)")
print("="*80)
# Out:
# ================================================================================
# Training Final Model with Best Parameters (5-Fold CV)
# ================================================================================

# %%
best_params = {
    'objective': 'regression',
    'metric': 'rmse',
    'boosting_type': 'gbdt',
    'verbosity': -1,
    'force_col_wise': True,
    'random_state': 42,
    **study.best_params
}

# %%
# Extract n_estimators separately
n_estimators = best_params.pop('n_estimators')

# %%
# 5-Fold CV for final model
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# %%
oof_predictions = np.zeros(len(X_train))
test_predictions = np.zeros(len(X_test))
feature_importance_df = pd.DataFrame()
cv_scores = []
cv_mae_scores = []
cv_r2_scores = []

# %%
for fold, (train_idx, val_idx) in enumerate(kf.split(X_train), 1):
    print(f"\nFold {fold}/{n_splits}")
    print("-" * 40)
    
    X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_tr, y_val = y_train[train_idx], y_train[val_idx]
    
    # Create LightGBM datasets
    train_data = lgb.Dataset(X_tr, label=y_tr, categorical_feature='auto')
    val_data = lgb.Dataset(X_val, label=y_val, reference=train_data, categorical_feature='auto')
    
    # Train model
    model = lgb.train(
        best_params,
        train_data,
        num_boost_round=n_estimators,
        valid_sets=[train_data, val_data],
        valid_names=['train', 'valid'],
        callbacks=[
            lgb.early_stopping(stopping_rounds=200, verbose=False),
            lgb.log_evaluation(period=500)
        ]
    )
    
    # Predictions
    oof_predictions[val_idx] = model.predict(X_val, num_iteration=model.best_iteration)
    test_predictions += model.predict(X_test, num_iteration=model.best_iteration) / n_splits
    
    # Calculate fold scores
    fold_rmse = np.sqrt(mean_squared_error(y_val, oof_predictions[val_idx]))
    fold_mae = mean_absolute_error(y_val, oof_predictions[val_idx])
    fold_r2 = r2_score(y_val, oof_predictions[val_idx])
    
    cv_scores.append(fold_rmse)
    cv_mae_scores.append(fold_mae)
    cv_r2_scores.append(fold_r2)
    
    print(f"Fold {fold} RMSE: {fold_rmse:,.2f}")
    print(f"Fold {fold} MAE: {fold_mae:,.2f}")
    print(f"Fold {fold} R²: {fold_r2:.4f}")
    print(f"Best iteration: {model.best_iteration}")
    
    # Feature importance
    fold_importance = pd.DataFrame({
        'feature': X_train.columns,
        'importance': model.feature_importance(importance_type='gain'),
        'fold': fold
    })
    feature_importance_df = pd.concat([feature_importance_df, fold_importance], axis=0)
# Out:
# Fold 1/5
# ----------------------------------------
# [500]	train's rmse: 32109.3	valid's rmse: 33948.8
# [1000]	train's rmse: 24782.7	valid's rmse: 27674.6
# [1500]	train's rmse: 23020.8	valid's rmse: 26460.6
# [2000]	train's rmse: 22059.6	valid's rmse: 25922.1
# [2500]	train's rmse: 21370.4	valid's rmse: 25603.1
# [3000]	train's rmse: 20840.2	valid's rmse: 25415.7
# [3500]	train's rmse: 20383.4	valid's rmse: 25289
# [4000]	train's rmse: 19990.1	valid's rmse: 25210.5
# [4500]	train's rmse: 19632.2	valid's rmse: 25141
# [5000]	train's rmse: 19307.1	valid's rmse: 25088.9
# [5500]	train's rmse: 19004.4	valid's rmse: 25050.2
# Fold 1 RMSE: 25,033.25
# Fold 1 MAE: 17,940.15
# Fold 1 R²: 0.9812
# Best iteration: 5891
#
# Fold 2/5
# ----------------------------------------
# [500]	train's rmse: 31962	valid's rmse: 34309.9
# [1000]	train's rmse: 24644.2	valid's rmse: 28169.3
# [1500]	train's rmse: 22889	valid's rmse: 26978.2
# [2000]	train's rmse: 21934.1	valid's rmse: 26443.2
# [2500]	train's rmse: 21259.4	valid's rmse: 26135.7
# [3000]	train's rmse: 20734.1	valid's rmse: 25954.4
# [3500]	train's rmse: 20288.6	valid's rmse: 25832.2
# [4000]	train's rmse: 19900.3	valid's rmse: 25751.1
# [4500]	train's rmse: 19548.7	valid's rmse: 25688.7
# [5000]	train's rmse: 19228.4	valid's rmse: 25640.3
# [5500]	train's rmse: 18923.8	valid's rmse: 25602.2
# Fold 2 RMSE: 25,583.98
# Fold 2 MAE: 18,175.95
# Fold 2 R²: 0.9808
# Best iteration: 5892
#
# Fold 3/5
# ----------------------------------------
# [500]	train's rmse: 32060	valid's rmse: 34147.3
# [1000]	train's rmse: 24739.4	valid's rmse: 27999.4
# [1500]	train's rmse: 22955.3	valid's rmse: 26835.6
# [2000]	train's rmse: 21998.5	valid's rmse: 26310.2
# [2500]	train's rmse: 21323	valid's rmse: 26005.4
# [3000]	train's rmse: 20795.8	valid's rmse: 25816.2
# [3500]	train's rmse: 20342.6	valid's rmse: 25689.2
# [4000]	train's rmse: 19954.9	valid's rmse: 25605.3
# [4500]	train's rmse: 19599.6	valid's rmse: 25537.2
# [5000]	train's rmse: 19280.1	valid's rmse: 25484.7
# [5500]	train's rmse: 18978.6	valid's rmse: 25442.6
# Fold 3 RMSE: 25,423.30
# Fold 3 MAE: 18,045.74
# Fold 3 R²: 0.9808
# Best iteration: 5895
#
# Fold 4/5
# ----------------------------------------
# [500]	train's rmse: 32139	valid's rmse: 33761.1
# [1000]	train's rmse: 24822.3	valid's rmse: 27417.5
# [1500]	train's rmse: 23053	valid's rmse: 26211.8
# [2000]	train's rmse: 22090.1	valid's rmse: 25678.5
# [2500]	train's rmse: 21405.1	valid's rmse: 25385
# [3000]	train's rmse: 20878.2	valid's rmse: 25217.7
# [3500]	train's rmse: 20420.5	valid's rmse: 25101.6
# [4000]	train's rmse: 20030.9	valid's rmse: 25031.7
# [4500]	train's rmse: 19671.2	valid's rmse: 24974
# [5000]	train's rmse: 19347	valid's rmse: 24934.9
# [5500]	train's rmse: 19039.8	valid's rmse: 24903.5
# Fold 4 RMSE: 24,888.02
# Fold 4 MAE: 17,827.68
# Fold 4 R²: 0.9816
# Best iteration: 5887
#
# Fold 5/5
# ----------------------------------------
# [500]	train's rmse: 32115.9	valid's rmse: 33852.4
# [1000]	train's rmse: 24778.1	valid's rmse: 27715.9
# [1500]	train's rmse: 22982	valid's rmse: 26534.3
# [2000]	train's rmse: 22021.4	valid's rmse: 26016.6
# [2500]	train's rmse: 21339.7	valid's rmse: 25715
# [3000]	train's rmse: 20812.9	valid's rmse: 25537.8
# [3500]	train's rmse: 20363.4	valid's rmse: 25416.1
# [4000]	train's rmse: 19975.9	valid's rmse: 25336.8
# [4500]	train's rmse: 19619.4	valid's rmse: 25273.8
# [5000]	train's rmse: 19299.1	valid's rmse: 25228.5
# [5500]	train's rmse: 18995.7	valid's rmse: 25188.1
# Fold 5 RMSE: 25,169.38
# Fold 5 MAE: 17,979.89
# Fold 5 R²: 0.9809
# Best iteration: 5888

# %%
# Overall CV scores
overall_rmse = np.sqrt(mean_squared_error(y_train, oof_predictions))
overall_mae = mean_absolute_error(y_train, oof_predictions)
overall_r2 = r2_score(y_train, oof_predictions)

# %%
print("\n" + "="*80)
print("FINAL RESULTS WITH OPTIMIZED HYPERPARAMETERS")
print("="*80)
print(f"\nOverall CV RMSE: {overall_rmse:,.2f} SGD")
print(f"Mean CV RMSE: {np.mean(cv_scores):,.2f} (+/- {np.std(cv_scores):,.2f}) SGD")
print(f"\nOverall CV MAE: {overall_mae:,.2f} SGD")
print(f"Mean CV MAE: {np.mean(cv_mae_scores):,.2f} (+/- {np.std(cv_mae_scores):,.2f}) SGD")
print(f"\nOverall CV R²: {overall_r2:.4f}")
print(f"Mean CV R²: {np.mean(cv_r2_scores):.4f} (+/- {np.std(cv_r2_scores):.4f})")
print(f"\nFold Scores:")
for i in range(len(cv_scores)):
    print(f"  Fold {i+1}: RMSE={cv_scores[i]:,.2f} SGD, MAE={cv_mae_scores[i]:,.2f} SGD, R²={cv_r2_scores[i]:.4f}")
# Out:
# ================================================================================
# FINAL RESULTS WITH OPTIMIZED HYPERPARAMETERS
# ================================================================================
#
# Overall CV RMSE: 25,220.86 SGD
# Mean CV RMSE: 25,219.59 (+/- 253.56) SGD
#
# Overall CV MAE: 17,993.88 SGD
# Mean CV MAE: 17,993.88 (+/- 115.36) SGD
#
# Overall CV R²: 0.9811
# Mean CV R²: 0.9811 (+/- 0.0003)
#
# Fold Scores:
#   Fold 1: RMSE=25,033.25 SGD, MAE=17,940.15 SGD, R²=0.9812
#   Fold 2: RMSE=25,583.98 SGD, MAE=18,175.95 SGD, R²=0.9808
#   Fold 3: RMSE=25,423.30 SGD, MAE=18,045.74 SGD, R²=0.9808
#   Fold 4: RMSE=24,888.02 SGD, MAE=17,827.68 SGD, R²=0.9816
#   Fold 5: RMSE=25,169.38 SGD, MAE=17,979.89 SGD, R²=0.9809

# %%
# Feature importance with percentage normalization
print("\n" + "="*80)
print("Top 10 Most Important Features:")
print("="*80)
feature_importance_summary = feature_importance_df.groupby('feature')['importance'].mean().sort_values(ascending=False)
# Out:
# ================================================================================
# Top 10 Most Important Features:
# ================================================================================

# %%
# Normalize to percentage
total_importance = feature_importance_summary.sum()
feature_importance_pct = (feature_importance_summary / total_importance * 100).sort_values(ascending=False)

# %%
# Display top 10 with percentage
print("\nFeature Importance (%):")
for feature, pct in feature_importance_pct.head(10).items():
    print(f"  {feature}: {pct:.2f}%")
# Out:
# Feature Importance (%):
#   FLOOR_AREA_SQM: 20.83%
#   STREET: 18.73%
#   RESALE_YEAR: 13.65%
#   FLAT_TYPE: 12.50%
#   TOWN: 7.61%
#   FLAT_MODEL: 6.93%
#   LEASE_COMMENCE_DATA: 5.23%
#   FLAT_AGE: 3.92%
#   LATITUDE: 2.36%
#   FLOOR_AVG: 2.13%

# %%
# Save feature importance with percentage
feature_importance_save = pd.DataFrame({
    'feature': feature_importance_pct.index,
    'importance_percentage': feature_importance_pct.values
})
feature_importance_save.to_csv('feature_importance_optimized_hyperopt.csv', index=False)
print("\nFeature importance saved to: feature_importance_optimized_hyperopt.csv")
# Out:
# Feature importance saved to: feature_importance_optimized_hyperopt.csv

# %%
# Visualize feature importance
print("\nGenerating feature importance visualization...")
plt.figure(figsize=(12, 8))
top_n = 10
top_features = feature_importance_pct.head(top_n)
plt.barh(range(len(top_features)), top_features.values)
plt.yticks(range(len(top_features)), top_features.index)
plt.xlabel('Importance (%)', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.title(f'Top {top_n} Feature Importance (Percentage) - LightGBM', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.savefig('feature_importance_plot.png', dpi=300, bbox_inches='tight')
print("Feature importance plot saved to: feature_importance_plot.png")
plt.close()
# Out:
# Generating feature importance visualization...
# Feature importance plot saved to: feature_importance_plot.png

# %%
# Create submission file
print("\n" + "="*80)
print("Creating Submission File")
print("="*80)
# Out:
# ================================================================================
# Creating Submission File
# ================================================================================

# %%
submission = pd.DataFrame({
    'Id': range(len(test_predictions)),
    'Predicted': test_predictions
})

# %%
submission.to_csv('submission_hyperopt.csv', index=False)
print(f"\nSubmission file saved: submission_hyperopt.csv")
print(f"Number of predictions: {len(submission)}")
print(f"\nPrediction Statistics:")
print(f"  Min: ${submission['Predicted'].min():,.2f}")
print(f"  Max: ${submission['Predicted'].max():,.2f}")
print(f"  Mean: ${submission['Predicted'].mean():,.2f}")
print(f"  Median: ${submission['Predicted'].median():,.2f}")
# Out:
# Submission file saved: submission_hyperopt.csv
# Number of predictions: 50000
#
# Prediction Statistics:
#   Min: $165,228.66
#   Max: $1,545,383.24
#   Mean: $517,817.95
#   Median: $487,617.17

# %%
# Save best parameters to file
with open('best_hyperparameters.txt', 'w') as f:
    f.write("Best Hyperparameters from Optuna Optimization\n")
    f.write("="*50 + "\n\n")
    f.write(f"CV RMSE: {overall_rmse:,.2f} SGD\n")
    f.write(f"Optuna Best Value: {study.best_value:,.2f} SGD\n\n")
    f.write("Parameters:\n")
    for key, value in study.best_params.items():
        f.write(f"  {key}: {value}\n")

# %%
print("\nBest parameters saved to: best_hyperparameters.txt")
# Out:
# Best parameters saved to: best_hyperparameters.txt

# %%
print("\n" + "="*80)
print("OPTIMIZATION COMPLETE!")
print("="*80)
# Out:
# ================================================================================
# OPTIMIZATION COMPLETE!
# ================================================================================
